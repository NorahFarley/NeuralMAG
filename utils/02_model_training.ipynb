# %% [markdown]
# # Baseline NeuralMAG UNet Training
# **Objective:** Train the unmodified, original spatial UNet to establish the baseline trajectory drift.
#
# **Methodology Replicated from Authors:**
# *   **Data:** 420,000 random samples trained simultaneously across sizes 32, 64, and 96 to enforce cross-scale generalizability.
# *   **Material:** Default parameters ($M_s=1000, A_x=0.5e-6, K_u=0$).
# *   **Hardware:** Nvidia GPU (CUDA).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import torch

# Verify GPU availability
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# Force the script to use primary GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
model_name = "model_original"
dataset_path = "/content/drive/MyDrive/NeuralMAG_Data/general_datasets"
base_path = "/content/drive/MyDrive/NeuralMAG_Data/NeuralMAG_Models"
#base_path = "/home/username/NeuralMAG_Data" # for VCU cluster

DOUBLE CHECK EVERYTHING

# !python train.py \
  --batch-size 100 --lr 0.005 --epochs 1000 --ntrain 300 --ntest 20 --kc 16 --inch 6 \
  --spin_file 'Spins.npy' --hd_file 'Hds.npy' \
  --model_name {model_name}.pt \
  --ckpt_path {base_path}/{model_name}_folder \
  --base_path {base_path}
  --path32 {dataset_path}/size32_general \
  --path64 {dataset_path}/size64_general \
  --path96 {dataset_path}/size96_general \
  --path128 '/content/local_data/datasets_128/data_Hd128_Hext0'
