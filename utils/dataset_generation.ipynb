# %% [markdown]
# If using Mac M2 -> change gpu=0 to gpu='mps'
# Also comment out google drive import and uncomment BASE_STORAGE
# Also will have to zip data in 50 seeds batches using terminal

# %%
# 1. Ensure the script has execution permissions on your system
# !chmod +x run2.sh

# 2. Run the script and stream the real-time console output directly into your notebook
# !./run2.sh
