# %% [markdown]
# # Baseline NeuralMAG UNet Training
# **Objective:** Train the unmodified, original spatial UNet to establish the baseline trajectory drift.
#
# **Methodology Replicated from Authors:**
# *   **Data:** 420,000 random samples trained simultaneously across sizes 32, 64, and 96 to enforce cross-scale generalizability.
# *   **Material:** Default parameters ($M_s=1000, A_x=0.5e-6, K_u=0$).
# *   **Hardware:** Nvidia GPU (CUDA).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch

# Verify GPU availability
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# Force the script to use primary GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# CUDA Available: True
# Device: NVIDIA A100-SXM4-80GB

# %%
os.chdir('/content/drive/MyDrive/NeuralMAG_Data/egs/demo/train')

# %%
# !python train.py \
  --batch-size 100 \
  --lr 0.005 \
  --epochs 1000 \
  --ntrain 300 \
  --ntest 20 \
  --kc 16 \
  --inch 6 \
  --spin_file "Spins.npy" \
  --hd_file "Hds.npy" \
  --model_name "model_original.pt" \
  --ckpt_path "/content/drive/MyDrive/NeuralMAG_Data/NeuralMAG_Models" \
  --path32 "/content/local_data/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size32_general" \
  --path64 "/content/local_data/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size64_general" \
  --path96 "/content/local_data/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size96_general" \
  --path128 "/content/local_data/content/drive/MyDrive/NeuralMAG_Data/datasets_128/Dataset/data_Hd128_Hext0"

# %%
# !python train.py \
--batch-size 10 \
--lr 0.005 \
--epochs 5 \
--ntrain 5 \
--ntest 2 \
--kc 16 \
--inch 6 \
--spin_file 'Spins.npy' \
--hd_file 'Hds.npy' \
--model_name 'model_test_run.pt' \
--ckpt_path '/content/drive/MyDrive/NeuralMAG_Data/NeuralMAG_Models' \
--path32 '/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size32_general' \
--path64 '/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size64_general' \
--path96 '/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size96_general' \
--path128 '/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size96_general'
# Out:
# loading data from:  ['/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size32_general']
# train seed number: 3
# test seed number: 2
# 0<= core number <=3, selected_percent: 0.83
# selected x y shape:  (1246, 6, 32, 32) (1246, 6, 32, 32)
#
# 0<= core number <=3, selected_percent: 0.84
# selected x y shape:  (842, 6, 32, 32) (842, 6, 32, 32)
#
# loading data from:  ['/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size64_general']
# train seed number: 3
# test seed number: 2
# 0<= core number <=3, selected_percent: 0.69
# selected x y shape:  (1033, 6, 64, 64) (1033, 6, 64, 64)
#
# 0<= core number <=3, selected_percent: 0.61
# selected x y shape:  (608, 6, 64, 64) (608, 6, 64, 64)
#
# loading data from:  ['/content/drive/MyDrive/NeuralMAG_Data/general_datasets/size96_general']
# train seed number: 3
# test seed number: 2
# 0<= core number <=3, selected_percent: 0.62
# selected x y shape:  (930, 6, 96, 96) (930, 6, 96, 96)
#
# 0<= core number <=3, selected_percent: 0.68
# ...
