# %% [markdown]
# If using Mac M2 -> change gpu=0 to gpu='mps'
# Also comment out google drive import and uncomment BASE_STORAGE
# Also will have to zip data in 50 seeds batches using terminal

# %%
# !nvidia-smi
# Out:
# Sun Jun 21 07:39:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             52W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive  
drive.mount('/content/drive')

# FOR MAC M2 ONLY
#BASE_STORAGE = "./NeuralMAG_Data"
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import random

# %%
# 2. Change to the ROOT folder (not the utils folder)
os.chdir('/content/drive/MyDrive/NeuralMAG_Data')

# %%
from utils.gen_data import prepare_model, simulate_spins, save_simulation_data
from libs.misc import initial_spin_prepare, create_random_mask
# Out:
# MAG2305 version: UnetHd_Public_2024.10.17

# %%
# 1. Global Setup
GRID_W = 64
TOTAL_SEEDS = 300       # To get 150k samples (140k train / 10k val)
MASK_THRESHOLD = 200    # First 200 seeds (2/3) get random masks

# %%
# 2. Argument Class (Simulates Command Line Args)
class Args:
    w = GRID_W
    layers = 2          # Bilayer thin film 
    Ms = 1000           # Default Saturation Magnetization 
    Ax = 0.5e-6         # Default Exchange constant 
    Ku = 0.0            # No anisotropy for training set 
    Kvec = (1.0, 0, 0)
    gpu = 0             # Use 0 for Colab; update to 'mps' logic if on M2
    sav_samples = 500   # To match original paper sample count 

    # need to define all below to avoid error like:  'Args' object has no attribute 'error_min'
    dtime = 1.0e-13       # CRITICAL: Physical time step in seconds 
    error_min = 1.0e-5    # Convergence threshold (error must drop below this) 
    max_iter = 50000      # Safety limit to prevent infinite loops 
    damping = 0.1           # Damping coefficient
    cell = (3, 3, 3)      # Cell size in nm

args = Args()

BASE_SAVE_DIR = f"/content/drive/MyDrive/NeuralMAG_Data/size{args.w}"

# %%
# Generate all seeds
for seed_id in range(TOTAL_SEEDS):
    is_masked = seed_id < MASK_THRESHOLD
    mask_label = "masked" if is_masked else "unmasked"
    
    # 1. Randomize External Field (100-1000 Oe) and orientation in-plane 
    Hext_val = np.random.uniform(100, 1000)
    theta = np.random.uniform(0, 2 * np.pi)
    Hext_vec = np.array([np.cos(theta), np.sin(theta), 0.0])
    Hext = Hext_val * Hext_vec

    # 2. Folder Naming: includes seed number, grid size, mask status, and Hext value
    seed_folder = f"seed_{seed_id:03d}_size{args.w}_{mask_label}_Hext_{int(Hext_val)}"
    seed_path = os.path.join(BASE_SAVE_DIR, f"size{args.w}_general", seed_folder)
    os.makedirs(seed_path, exist_ok=True)

    # 3. Model and Spin Initialization 
    film = prepare_model(args)
    # Randomized magnetization within the film plane (X-Y) 
    spin = initial_spin_prepare(args.w, args.layers, seed_id) 

    if is_masked:
        # Random polygon generation using authors' randomization parameters
        mask = create_random_mask((args.w, args.w), np.random.randint(2, args.w), random.choice([True, False]))
        # Physically set magnetization to zero in the masked area 
        spin = film.SpinInit(spin * mask)
    else:
        spin = film.SpinInit(spin)

    print(f"--- Seed {seed_id:03d} | Hext: {Hext_val:.1f} Oe | {mask_label} ---")
    
    # 4. Run FFT/LLG simulation and return trajectory lists 
    Spins_list, Hds_list, error_list = simulate_spins(film, spin, Hext, args)

    # 5. Save all three data types per seed (Calls modified save_simulation_data)
    save_simulation_data(Spins_list, Hds_list, args, seed_path, error_list, Hext)

print(f"Generation Complete for Size {args.w}x{args.w}.")
# Out:
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.240019 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 000 | Hext: 578.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.988386 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 001 | Hext: 806.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.988681 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 002 | Hext: 460.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.016075 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 003 | Hext: 873.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.986997 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 004 | Hext: 741.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.990424 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 005 | Hext: 240.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.994545 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 006 | Hext: 335.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.009631 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 007 | Hext: 965.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.994342 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 008 | Hext: 945.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.991089 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 009 | Hext: 240.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.984121 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 010 | Hext: 696.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.006431 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 011 | Hext: 920.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.004146 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 012 | Hext: 253.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.991245 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 013 | Hext: 978.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.006794 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 014 | Hext: 571.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.993659 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 015 | Hext: 537.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.010555 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 016 | Hext: 945.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.985512 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 017 | Hext: 118.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.996606 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 018 | Hext: 496.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.018234 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 019 | Hext: 350.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.033465 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 020 | Hext: 480.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.017504 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 021 | Hext: 131.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.005257 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 022 | Hext: 758.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.014018 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 023 | Hext: 945.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.020544 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 024 | Hext: 276.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.010343 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 025 | Hext: 179.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.000372 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 026 | Hext: 141.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.990296 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 027 | Hext: 428.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.004409 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 028 | Hext: 548.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.976876 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 029 | Hext: 586.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.038128 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 030 | Hext: 900.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.041958 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 031 | Hext: 757.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.031994 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 032 | Hext: 444.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.034529 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 033 | Hext: 433.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.040962 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 034 | Hext: 292.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.044452 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 035 | Hext: 971.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.034778 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 036 | Hext: 344.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.033931 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 037 | Hext: 686.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.000997 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 038 | Hext: 229.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.009724 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 039 | Hext: 806.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.987094 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 040 | Hext: 292.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.064760 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 041 | Hext: 569.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.043041 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 042 | Hext: 838.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.038399 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 043 | Hext: 611.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.051974 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 044 | Hext: 253.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.989080 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 045 | Hext: 592.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.030495 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 046 | Hext: 641.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.044366 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 047 | Hext: 646.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.037764 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 048 | Hext: 426.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.041301 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 049 | Hext: 421.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.038943 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 050 | Hext: 154.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.032937 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 051 | Hext: 945.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.046489 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 052 | Hext: 399.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.008989 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 053 | Hext: 362.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.021881 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 054 | Hext: 279.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.020385 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 055 | Hext: 695.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.049620 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 056 | Hext: 214.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.044409 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 057 | Hext: 253.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.040684 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 058 | Hext: 429.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.026009 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 059 | Hext: 253.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# ...
#
# Time cost: 1.018603 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 279 | Hext: 420.5 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.015069 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 280 | Hext: 796.3 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.010587 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 281 | Hext: 720.8 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.011064 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 282 | Hext: 848.6 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.019281 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 283 | Hext: 887.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.013155 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 284 | Hext: 930.4 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.027753 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 285 | Hext: 705.4 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 0.989345 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 286 | Hext: 998.4 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.026273 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 287 | Hext: 551.6 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.015413 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 288 | Hext: 602.0 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.018683 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 289 | Hext: 866.9 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.021084 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 290 | Hext: 341.4 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.012973 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 291 | Hext: 452.1 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.014859 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 292 | Hext: 477.7 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.015068 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 293 | Hext: 807.9 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.018569 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 294 | Hext: 628.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.021894 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 295 | Hext: 766.9 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.027013 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 296 | Hext: 292.8 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.021045 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 297 | Hext: 219.9 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.021483 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 298 | Hext: 780.6 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 8192
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.63859e-01 -1.68257e-01 -9.16506e-02]
#   [-1.68257e-01  2.63859e-01 -9.16506e-02]
#   [-9.16506e-02 -9.16506e-02  4.72282e-01]
#   trace = 1.00000
#
# Time cost: 1.020642 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 299 | Hext: 689.5 Oe | unmasked ---
# Generation Complete for Size 64x64.
