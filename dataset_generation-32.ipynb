# %% [markdown]
# If using Mac M2 -> change gpu=0 to gpu='mps'
# Also comment out google drive import and uncomment BASE_STORAGE
# Also will have to zip data in 50 seeds batches using terminal

# %%
# !nvidia-smi
# Out:
# Sun Jun 21 07:21:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   32C    P0             56W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive  
drive.mount('/content/drive')

# FOR MAC M2 ONLY
#BASE_STORAGE = "./NeuralMAG_Data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import random

# %%
# 2. Change to the ROOT folder (not the utils folder)
os.chdir('/content/drive/MyDrive/NeuralMAG_Data')

# %%
from utils.gen_data import prepare_model, simulate_spins, save_simulation_data
from libs.misc import initial_spin_prepare, create_random_mask
# Out:
# MAG2305 version: UnetHd_Public_2024.10.17

# %%
# 1. Global Setup
GRID_W = 32
TOTAL_SEEDS = 300       # To get 150k samples (140k train / 10k val)
MASK_THRESHOLD = 200    # First 200 seeds (2/3) get random masks

# %%
# 2. Argument Class (Simulates Command Line Args)
class Args:
    w = GRID_W
    layers = 2          # Bilayer thin film 
    Ms = 1000           # Default Saturation Magnetization 
    Ax = 0.5e-6         # Default Exchange constant 
    Ku = 0.0            # No anisotropy for training set 
    Kvec = (1.0, 0, 0)
    gpu = 0             # Use 0 for Colab; update to 'mps' logic if on M2
    sav_samples = 500   # To match original paper sample count 

    # need to define all below to avoid error like:  'Args' object has no attribute 'error_min'
    dtime = 1.0e-13       # CRITICAL: Physical time step in seconds 
    error_min = 1.0e-5    # Convergence threshold (error must drop below this) 
    max_iter = 50000      # Safety limit to prevent infinite loops 
    damping = 0.1           # Damping coefficient
    cell = (3, 3, 3)      # Cell size in nm

args = Args()
BASE_SAVE_DIR = f"/content/drive/MyDrive/NeuralMAG_Data/size{args.w}"

# %%
# Generate all seeds
for seed_id in range(TOTAL_SEEDS):
    is_masked = seed_id < MASK_THRESHOLD
    mask_label = "masked" if is_masked else "unmasked"
    
    # 1. Randomize External Field (100-1000 Oe) and orientation in-plane 
    Hext_val = np.random.uniform(100, 1000)
    theta = np.random.uniform(0, 2 * np.pi)
    Hext_vec = np.array([np.cos(theta), np.sin(theta), 0.0])
    Hext = Hext_val * Hext_vec

    # 2. Folder Naming: includes seed number, grid size, mask status, and Hext value
    seed_folder = f"seed_{seed_id:03d}_size{args.w}_{mask_label}_Hext_{int(Hext_val)}"
    seed_path = os.path.join(BASE_SAVE_DIR, f"size{args.w}_general", seed_folder)
    os.makedirs(seed_path, exist_ok=True)

    # 3. Model and Spin Initialization 
    film = prepare_model(args)
    # Randomized magnetization within the film plane (X-Y) 
    spin = initial_spin_prepare(args.w, args.layers, seed_id) 

    if is_masked:
        # Random polygon generation using authors' randomization parameters
        mask = create_random_mask((args.w, args.w), np.random.randint(2, args.w), random.choice([True, False]))
        # Physically set magnetization to zero in the masked area 
        spin = film.SpinInit(spin * mask)
    else:
        spin = film.SpinInit(spin)

    print(f"--- Seed {seed_id:03d} | Hext: {Hext_val:.1f} Oe | {mask_label} ---")
    
    # 4. Run FFT/LLG simulation and return trajectory lists 
    Spins_list, Hds_list, error_list = simulate_spins(film, spin, Hext, args)

    # 5. Save all three data types per seed (Calls modified save_simulation_data)
    save_simulation_data(Spins_list, Hds_list, args, seed_path, error_list, Hext)

print(f"Generation Complete for Size {args.w}x{args.w}.")
# Out:
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.482820 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 000 | Hext: 875.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.257033 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 001 | Hext: 760.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.257367 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 002 | Hext: 240.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.261416 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 003 | Hext: 451.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.262348 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 004 | Hext: 298.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.255855 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 005 | Hext: 737.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.253345 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 006 | Hext: 641.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.258855 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 007 | Hext: 572.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.257916 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 008 | Hext: 217.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.257388 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 009 | Hext: 854.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260630 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 010 | Hext: 928.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.276286 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 011 | Hext: 107.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.259218 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 012 | Hext: 482.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260434 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 013 | Hext: 336.4 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.274053 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 014 | Hext: 646.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266247 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 015 | Hext: 331.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271053 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 016 | Hext: 114.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.253074 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 017 | Hext: 562.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.258787 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 018 | Hext: 394.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260064 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 019 | Hext: 253.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.264147 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 020 | Hext: 441.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266885 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 021 | Hext: 510.5 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271541 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 022 | Hext: 390.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.265598 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 023 | Hext: 362.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.262618 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 024 | Hext: 758.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.262337 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 025 | Hext: 173.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260821 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 026 | Hext: 362.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.262995 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 027 | Hext: 362.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.283373 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 028 | Hext: 650.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.275074 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 029 | Hext: 562.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.264316 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 030 | Hext: 279.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.254478 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 031 | Hext: 503.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.253837 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 032 | Hext: 711.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.259356 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 033 | Hext: 799.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.255162 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 034 | Hext: 506.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.281608 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 035 | Hext: 263.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.283787 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 036 | Hext: 470.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.265425 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 037 | Hext: 134.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266566 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 038 | Hext: 513.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.256854 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 039 | Hext: 512.0 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.261198 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 040 | Hext: 362.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266315 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 041 | Hext: 388.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260608 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 042 | Hext: 291.1 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.265224 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 043 | Hext: 562.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.262889 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 044 | Hext: 627.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.261569 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 045 | Hext: 829.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.284222 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 046 | Hext: 650.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260639 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 047 | Hext: 849.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.276132 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 048 | Hext: 287.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.260480 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 049 | Hext: 468.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.278981 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 050 | Hext: 638.8 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.285074 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 051 | Hext: 566.9 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271620 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 052 | Hext: 650.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.282808 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 053 | Hext: 351.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.265278 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 054 | Hext: 572.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.287790 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 055 | Hext: 473.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.284199 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 056 | Hext: 279.7 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.273994 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 057 | Hext: 842.3 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266432 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 058 | Hext: 793.6 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.269674 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 059 | Hext: 223.2 Oe | masked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# ...
#
# Time cost: 0.291681 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 279 | Hext: 728.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.324416 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 280 | Hext: 201.5 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.261541 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 281 | Hext: 811.3 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.309959 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 282 | Hext: 479.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.313203 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 283 | Hext: 211.8 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.272269 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 284 | Hext: 397.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.295957 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 285 | Hext: 364.9 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.298783 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 286 | Hext: 382.0 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.275278 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 287 | Hext: 990.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.295595 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 288 | Hext: 339.5 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271084 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 289 | Hext: 278.0 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271509 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 290 | Hext: 874.7 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.267289 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 291 | Hext: 855.5 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.301986 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 292 | Hext: 341.2 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.267797 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 293 | Hext: 856.7 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.267261 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 294 | Hext: 887.6 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.271873 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 295 | Hext: 804.4 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.275193 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 296 | Hext: 451.7 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.263327 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 297 | Hext: 984.7 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.259907 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 298 | Hext: 231.6 Oe | unmasked ---
#
# Initialize an mmModel:
#
#   Cuda:0 available. Spin evolution using cuda:0.
#
#   # Cells  : 2048
#   # Matters: 1
#   Ms check : 1st 1000.000, last 1000.000   [emu/cc]
#   Ax check : 1st 5.00e-07, last 5.00e-07   [erg/cm]
#   Ku check : 1st 0.00e+00, last 0.00e+00   [erg/cc]
#
#   Average magnetization  :   1000.00  [emu/cc]
#   Maximal anisotropy Hk  : 0.000e+00  [Oe]
#   Maximal Heisenberg Hx  : 1.111e+04  [Oe]
#   Maximal effective Heff : 7.923e+04  [Oe]
#
# Creating 2 layer models
#
# Demag Matrix SumTest:
#   [ 2.65687e-01 -1.64968e-01 -9.15766e-02]
#   [-1.64968e-01  2.65687e-01 -9.15766e-02]
#   [-9.15766e-02 -9.15766e-02  4.68626e-01]
#   trace = 1.00000
#
# Time cost: 0.266133 s for initializing demag matrix
#
# Spin state initialized according to input.
#
# --- Seed 299 | Hext: 816.6 Oe | unmasked ---
# Generation Complete for Size 32x32.
